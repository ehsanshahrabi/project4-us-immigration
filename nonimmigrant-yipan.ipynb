# %%
import pandas as pd
import plotly.graph_objects as go

# %%
# Load file
nonimmsuptable_country = "2022_xxxx_plcy_nonimmigrants_fy2021_supplemental_tables/fy2021_nonimmsuptable1d.xlsx"
nonimmsuptable_state = "2022_xxxx_plcy_nonimmigrants_fy2021_supplemental_tables/fy2021_nonimmsuptable3d.xlsx"


# Read excel
nonimmsuptable_country = pd.read_excel(nonimmsuptable_country, header=None)
nonimmsuptable_state = pd.read_excel(nonimmsuptable_state, header=None)

# Remove first 3 rows that is irralevent and set header and index
nonimmsuptable_country = nonimmsuptable_country.drop(nonimmsuptable_country.index[0:3])
nonimmsuptable_country = nonimmsuptable_country.reset_index(drop=True)
nonimmsuptable_country = nonimmsuptable_country.set_axis(nonimmsuptable_country.iloc[0],axis = "columns")
nonimmsuptable_country = nonimmsuptable_country[2:]
# nonimmsuptable_country = nonimmsuptable_country.set_index(nonimmsuptable_country.columns[0])
nonimmsuptable_country = nonimmsuptable_country.drop("Total", axis=1)

nonimmsuptable_state = nonimmsuptable_state.drop(nonimmsuptable_state.index[0:3])
nonimmsuptable_state = nonimmsuptable_state.reset_index(drop=True)
nonimmsuptable_state = nonimmsuptable_state.set_axis(nonimmsuptable_state.iloc[0],axis = "columns")
nonimmsuptable_state = nonimmsuptable_state[2:]
# nonimmsuptable_state = nonimmsuptable_state.set_index(nonimmsuptable_state.columns[0])
nonimmsuptable_state = nonimmsuptable_state.drop("Total", axis=1)

# %%
nonimmsuptable_country.head()
# Out:
# 0 Class                                        Description Afghanistan  \
# 2    A1  Foreign government officials and families: amb...          52
# 3    A2  Foreign government officials and families: oth...         197
# 4    A3  Foreign government officials and families: att...           -
# 5    B1                   Temporary visitors: for business          46
# 6    B2                   Temporary visitors: for pleasure         357
#
# 0 Albania Algeria Andorra Angola Antigua and Barbuda Argentina Armenia  ...  \
# 2      47      78      13    102                  34       180      54  ...
# 3      43      98       6    111                  26       416      49  ...
# 4       -       -       -      D                   -         -       -  ...
# 5     121      73       4     84                 217      9093     220  ...
# 6    6380     408       6    476                5039    215345    8301  ...
#
# 0 United Kingdom9 Uruguay Uzbekistan Vanuatu Venezuela Vietnam Yemen Zambia  \
# ...

# %%
nonimmsuptable_state.head()
# Out:
# 0 Class                                        Description Alabama Alaska  \
# 2    A1  Foreign government officials and families: amb...      26     11
# 3    A2  Foreign government officials and families: oth...     672    318
# 4    A3  Foreign government officials and families: att...       -      D
# 5    B1                   Temporary visitors: for business    8576   1676
# 6    B2                   Temporary visitors: for pleasure   14542  38014
#
# 0 Arizona Arkansas California Colorado Connecticut Delaware  ...    Texas  \
# 2     402       18       1858       67          43        4  ...     1893
# 3    3102       88       6746      577         142      495  ...     9308
# 4       D        -        145        D           4        -  ...       22
# 5   36082     3207     337325    14347        2340     1051  ...   216535
# 6  143696    11619     993128   109963       42357     6924  ...  1363939
#
# ...

# %%
# Unpivot tables

nonimmsuptable_country = pd.melt(nonimmsuptable_country, id_vars = ["Class", "Description"], var_name = "country", value_name="population_count")
nonimmsuptable_state = pd.melt(nonimmsuptable_state, id_vars = ["Class", "Description"], var_name = "state", value_name="population_count")

# nonimmsuptable_country.info

# Filter Visa Type
# nonimmsuptable_country = nonimmsuptable_country.loc[:,nonimmsuptable_country.columns[nonimmsuptable_country["Class"].isin(["F1","F2","F3","H1B","H1B1","H4","K1","K2"])]]
# nonimmsuptable_state = nonimmsuptable_state["F1","F2","F3","H1B","H1B1","H4","K1","K2"]

# %%
nonimmsuptable_country.head()
# Out:
#   Class                                        Description      country  \
# 0    A1  Foreign government officials and families: amb...  Afghanistan
# 1    A2  Foreign government officials and families: oth...  Afghanistan
# 2    A3  Foreign government officials and families: att...  Afghanistan
# 3    B1                   Temporary visitors: for business  Afghanistan
# 4    B2                   Temporary visitors: for pleasure  Afghanistan
#
#   population_count
# 0               52
# 1              197
# 2                -
# 3               46
# 4              357

# %%
nonimmsuptable_state.head()
# Out:
#   Class                                        Description    state  \
# 0    A1  Foreign government officials and families: amb...  Alabama
# 1    A2  Foreign government officials and families: oth...  Alabama
# 2    A3  Foreign government officials and families: att...  Alabama
# 3    B1                   Temporary visitors: for business  Alabama
# 4    B2                   Temporary visitors: for pleasure  Alabama
#
#   population_count
# 0               26
# 1              672
# 2                -
# 3             8576
# 4            14542
