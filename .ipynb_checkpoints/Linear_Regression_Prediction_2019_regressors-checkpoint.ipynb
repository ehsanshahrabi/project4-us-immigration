# %%
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import sqlite3
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from prophet import Prophet
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error, median_absolute_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# %%
immigration_data_2012_2021 = "Resources/immigration_data_2005_2021.csv"
#state_unemployment = "Resources/emp-unemployment.xls"
#gini = "Resources/gini_index_by_state_2016_2018.xlsx"

# %%
inmigration = pd.read_csv(immigration_data_2012_2021)
inmigration.head()
# Out:
#    Year Region and country of birth  Total Permanent Residents  Percentage  \
# 0  2005                       Total                    1122373      100.00
# 1  2005    China, People's Republic                      69967        6.23
# 2  2005          Dominican Republic                      27504        2.45
# 3  2005                       India                      84681        7.54
# 4  2005                        Iran                      13887        1.24
#
#    Alabama  Alaska  Arizona  Arkansas  California  Colorado  ...  Virginia  \
# 0     4200    1525    18988      2698      232023     11977  ...     27100
# 1      328      92      543       202       17668       765  ...      1327
# 2        5      42       22         0          82         6  ...        90
# 3      431      15      739       215       14724       516  ...      2776
# 4       48       4      285         9        7059       131  ...       562
#
#    Washington  West Virginia  Wisconsin  Wyoming  U.S. Armed Services posts  \
# 0       26482            847       7909      321                        128
# 1        1508            101        593       28                         13
# 2          18              6         39        0                          0
# 3        1747            133        876        0                          0
# 4         318             18         48        0                          0
#
#    U.S. possessions  U.S. Dependencies  Guam  Puerto Rico
# 0              5868                  0     0            0
# 1               184                  0     0            0
# 2              2346                  0     0            0
# 3                24                  0     0            0
# 4                 0                  0     0            0
#
# [5 rows x 60 columns]

# %% [markdown]
# ## Cleaning country regressor dataset

# %%
#Read the csv
countries_raw_metadata = pd.read_csv("Resources/countries_metadata.csv", encoding='latin-1')
display(countries_raw_metadata.head())
print(countries_raw_metadata.shape)
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
#
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS
# 3           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 4               Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
#
#       1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 0         667070000         660330000         665770000         682335000
# 1  89.5202179159242  75.8055639067957  70.9091553472599  74.3133748233246
# 2                ..                ..                ..                ..
# 3            16.203            16.708            17.226            17.757
# 4             20.86             18.02             37.01             43.37
#
#       1964 [YR1964]     1965 [YR1965]  ...     2013 [YR2013]  \
# 0         698355000         715185000  ...        1363240000
# 1  85.4982461036748  98.4864217470782  ...  7020.38568208449
# 2                ..                ..  ...              4.05
# 3            18.299            18.086  ...            53.013
# 4             39.14             37.88  ...             13.03
#
#       2014 [YR2014]     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]  \
# 0        1371860000        1379860000        1387790000        1396215000
# 1  7636.07422276004  8016.44601585644  8094.39037512163  8817.04549566316
# 2               4.1                ..                ..               3.9
# 3            54.259              55.5            56.736             57.96
# 4             13.83             11.99             13.57             12.64
#
#   2018 [YR2018]     2019 [YR2019]     2020 [YR2020]     2021 [YR2021]  \
# 0  1.402760e+09        1407745000        1411100000        1412360000
# 1  9.905406e+03  10143.8602060373  10408.7191247747  12617.5049863004
# 2  4.930000e+00              5.15              5.61              5.11
# 3  5.915200e+01            60.308            61.428            62.512
# 4  1.086000e+01             10.41              8.52              7.52
#
#       2022 [YR2022]
# 0        1412175000
# 1  12720.2156397612
# 2                ..
# 3             63.56
# 4                ..
#
# [5 rows x 67 columns]
# (70, 67)

# %%
#Delete the "[YR..]" in the year columns
for column in countries_raw_metadata.columns:
    if "[YR" in column:
        new_column_name = column.split("[")[0].strip() # Extract the part before '[YR' and remove any leading/trailing spaces
        countries_raw_metadata.rename(columns={column: new_column_name}, inplace=True)
countries_raw_metadata.head()
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
#
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS
# 3           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 4               Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
#
#                1960              1961              1962              1963  \
# 0         667070000         660330000         665770000         682335000
# 1  89.5202179159242  75.8055639067957  70.9091553472599  74.3133748233246
# 2                ..                ..                ..                ..
# 3            16.203            16.708            17.226            17.757
# 4             20.86             18.02             37.01             43.37
#
#                1964              1965  ...              2013  \
# 0         698355000         715185000  ...        1363240000
# 1  85.4982461036748  98.4864217470782  ...  7020.38568208449
# 2                ..                ..  ...              4.05
# 3            18.299            18.086  ...            53.013
# 4             39.14             37.88  ...             13.03
#
#                2014              2015              2016              2017  \
# 0        1371860000        1379860000        1387790000        1396215000
# 1  7636.07422276004  8016.44601585644  8094.39037512163  8817.04549566316
# 2               4.1                ..                ..               3.9
# 3            54.259              55.5            56.736             57.96
# 4             13.83             11.99             13.57             12.64
#
#            2018              2019              2020              2021  \
# 0  1.402760e+09        1407745000        1411100000        1412360000
# 1  9.905406e+03  10143.8602060373  10408.7191247747  12617.5049863004
# 2  4.930000e+00              5.15              5.61              5.11
# 3  5.915200e+01            60.308            61.428            62.512
# 4  1.086000e+01             10.41              8.52              7.52
#
#                2022
# 0        1412175000
# 1  12720.2156397612
# 2                ..
# 3             63.56
# 4                ..
#
# [5 rows x 67 columns]

# %%
#Clean the "Country Names" columns 
unique_names = countries_raw_metadata["Country Name"].unique()
unique_names
# Out:
# array(['China', 'United States', 'Iran, Islamic Rep.', 'India',
#        'Dominican Republic', 'Mexico', 'United Kingdom', 'Pakistan',
#        'Philippines', nan,
#        'Data from database: World Development Indicators',
#        'Last Updated: 06/29/2023', 'Code', 'SP.POP.TOTL',
#        'NY.GDP.PCAP.CD', 'SL.UEM.TOTL.NE.ZS',
#        'Unemployment is a key measure to monitor whether a country is on track to achieve the Sustainable Development Goal of promoting sustained',
#        'However', 'SP.URB.TOTL.IN.ZS',
#        "Percentages urban are the numbers of persons residing in an area defined as ''urban'' per 100 total population. They are calculated by the Statistics Division of the United Nations Department of Economic and Social Affairs. Particular caution should be used in interpreting the figures for percentage urban for different countries.",
#        'Countries differ in the way they classify population as "urban" or "rural." The population of a city or metropolitan area depends on the boundaries chosen.',
#        'SP.DYN.CBRT.IN', 'SI.POV.GINI'], dtype=object)

# %%
#List the country names we want to keep.
attributes_to_keep = ['China', 'United States', 'Iran, Islamic Rep.', 'India', 'Dominican Republic', 'Mexico', 'United Kingdom', 'Pakistan', 'Philippines']

# Filter the DataFrame to keep only the desired attributes
df_filtered = countries_raw_metadata[countries_raw_metadata['Country Name'].isin(attributes_to_keep)]

# Print the filtered DataFrame
df_filtered.head()
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
#
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.NE.ZS
# 3           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 4               Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
#
#                1960              1961              1962              1963  \
# 0         667070000         660330000         665770000         682335000
# 1  89.5202179159242  75.8055639067957  70.9091553472599  74.3133748233246
# 2                ..                ..                ..                ..
# 3            16.203            16.708            17.226            17.757
# 4             20.86             18.02             37.01             43.37
#
#                1964              1965  ...              2013  \
# 0         698355000         715185000  ...        1363240000
# 1  85.4982461036748  98.4864217470782  ...  7020.38568208449
# 2                ..                ..  ...              4.05
# 3            18.299            18.086  ...            53.013
# 4             39.14             37.88  ...             13.03
#
#                2014              2015              2016              2017  \
# 0        1371860000        1379860000        1387790000        1396215000
# 1  7636.07422276004  8016.44601585644  8094.39037512163  8817.04549566316
# 2               4.1                ..                ..               3.9
# 3            54.259              55.5            56.736             57.96
# 4             13.83             11.99             13.57             12.64
#
#            2018              2019              2020              2021  \
# 0  1.402760e+09        1407745000        1411100000        1412360000
# 1  9.905406e+03  10143.8602060373  10408.7191247747  12617.5049863004
# 2  4.930000e+00              5.15              5.61              5.11
# 3  5.915200e+01            60.308            61.428            62.512
# 4  1.086000e+01             10.41              8.52              7.52
#
#                2022
# 0        1412175000
# 1  12720.2156397612
# 2                ..
# 3             63.56
# 4                ..
#
# [5 rows x 67 columns]

# %%
#Prepare the "Series Name" to move it to the columns, these will be our regressors. 
series_names = df_filtered["Series Name"].unique()
series_names
# Out:
# array(['Population, total', 'GDP per capita (current US$)',
#        'Unemployment, total (% of total labor force) (national estimate)',
#        'Urban population (% of total population)',
#        'Birth rate, crude (per 1,000 people)', 'Gini index'], dtype=object)

# %%
df_filtered.loc[df_filtered["Series Name"] == 'Population, total', "Series Name"] = "Population_total"
df_filtered.loc[df_filtered["Series Name"] == 'GDP per capita (current US$)', "Series Name"] = "GDP_per_capita"
df_filtered.loc[df_filtered["Series Name"] == 'Unemployment, total (% of total labor force) (national estimate)', "Series Name"] = "UR"
df_filtered.loc[df_filtered["Series Name"] == 'Urban population (% of total population)', "Series Name"] = "Urban_population"
df_filtered.loc[df_filtered["Series Name"] == 'Birth rate, crude (per 1,000 people)', "Series Name"] = "Birth_rate_crude"
df_filtered.loc[df_filtered["Series Name"] == 'Gini index', "Series Name"] = "Gini_index"
df_filtered.loc[df_filtered["Country Name"] == 'Iran, Islamic Rep.', "Country Name"] = "Iran"
df_filtered
# Out:
#           Country Name Country Code       Series Name        Series Code  \
# 0                China          CHN  Population_total        SP.POP.TOTL
# 1                China          CHN    GDP_per_capita     NY.GDP.PCAP.CD
# 2                China          CHN                UR  SL.UEM.TOTL.NE.ZS
# 3                China          CHN  Urban_population  SP.URB.TOTL.IN.ZS
# 4                China          CHN  Birth_rate_crude     SP.DYN.CBRT.IN
# 5                China          CHN        Gini_index        SI.POV.GINI
# 6        United States          USA  Population_total        SP.POP.TOTL
# 7        United States          USA    GDP_per_capita     NY.GDP.PCAP.CD
# 8        United States          USA                UR  SL.UEM.TOTL.NE.ZS
# 9        United States          USA  Urban_population  SP.URB.TOTL.IN.ZS
# 10       United States          USA  Birth_rate_crude     SP.DYN.CBRT.IN
# 11       United States          USA        Gini_index        SI.POV.GINI
# 12                Iran          IRN  Population_total        SP.POP.TOTL
# 13                Iran          IRN    GDP_per_capita     NY.GDP.PCAP.CD
# 14                Iran          IRN                UR  SL.UEM.TOTL.NE.ZS
# 15                Iran          IRN  Urban_population  SP.URB.TOTL.IN.ZS
# 16                Iran          IRN  Birth_rate_crude     SP.DYN.CBRT.IN
# 17                Iran          IRN        Gini_index        SI.POV.GINI
# 18               India          IND  Population_total        SP.POP.TOTL
# 19               India          IND    GDP_per_capita     NY.GDP.PCAP.CD
# 20               India          IND                UR  SL.UEM.TOTL.NE.ZS
# 21               India          IND  Urban_population  SP.URB.TOTL.IN.ZS
# 22               India          IND  Birth_rate_crude     SP.DYN.CBRT.IN
# 23               India          IND        Gini_index        SI.POV.GINI
# 24  Dominican Republic          DOM  Population_total        SP.POP.TOTL
# 25  Dominican Republic          DOM    GDP_per_capita     NY.GDP.PCAP.CD
# 26  Dominican Republic          DOM                UR  SL.UEM.TOTL.NE.ZS
# 27  Dominican Republic          DOM  Urban_population  SP.URB.TOTL.IN.ZS
# 28  Dominican Republic          DOM  Birth_rate_crude     SP.DYN.CBRT.IN
# 29  Dominican Republic          DOM        Gini_index        SI.POV.GINI
# 30              Mexico          MEX  Population_total        SP.POP.TOTL
# 31              Mexico          MEX    GDP_per_capita     NY.GDP.PCAP.CD
# 32              Mexico          MEX                UR  SL.UEM.TOTL.NE.ZS
# 33              Mexico          MEX  Urban_population  SP.URB.TOTL.IN.ZS
# 34              Mexico          MEX  Birth_rate_crude     SP.DYN.CBRT.IN
# 35              Mexico          MEX        Gini_index        SI.POV.GINI
# 36      United Kingdom          GBR  Population_total        SP.POP.TOTL
# 37      United Kingdom          GBR    GDP_per_capita     NY.GDP.PCAP.CD
# 38      United Kingdom          GBR                UR  SL.UEM.TOTL.NE.ZS
# 39      United Kingdom          GBR  Urban_population  SP.URB.TOTL.IN.ZS
# 40      United Kingdom          GBR  Birth_rate_crude     SP.DYN.CBRT.IN
# 41      United Kingdom          GBR        Gini_index        SI.POV.GINI
# 42            Pakistan          PAK  Population_total        SP.POP.TOTL
# 43            Pakistan          PAK    GDP_per_capita     NY.GDP.PCAP.CD
# 44            Pakistan          PAK                UR  SL.UEM.TOTL.NE.ZS
# 45            Pakistan          PAK  Urban_population  SP.URB.TOTL.IN.ZS
# 46            Pakistan          PAK  Birth_rate_crude     SP.DYN.CBRT.IN
# 47            Pakistan          PAK        Gini_index        SI.POV.GINI
# 48         Philippines          PHL  Population_total        SP.POP.TOTL
# 49         Philippines          PHL    GDP_per_capita     NY.GDP.PCAP.CD
# 50         Philippines          PHL                UR  SL.UEM.TOTL.NE.ZS
# 51         Philippines          PHL  Urban_population  SP.URB.TOTL.IN.ZS
# 52         Philippines          PHL  Birth_rate_crude     SP.DYN.CBRT.IN
# 53         Philippines          PHL        Gini_index        SI.POV.GINI
#
#                 1960              1961              1962              1963  \
# 0          667070000         660330000         665770000         682335000
# 1   89.5202179159242  75.8055639067957  70.9091553472599  74.3133748233246
# 2                 ..                ..                ..                ..
# 3             16.203            16.708            17.226            17.757
# 4              20.86             18.02             37.01             43.37
# 5                 ..                ..                ..                ..
# 6          180671000         183691000         186538000         189242000
# 7   3007.12344537862  3066.56286916615  3243.84307754988  3374.51517105082
# 8                5.5               6.7               5.5               5.7
# 9             69.996            70.377            70.757            71.134
# 10              23.7              23.3              22.4              21.7
# 11                ..                ..                ..                ..
# 12          21388806          21983622          22605050          23259094
# 13  196.323926903847  201.374873094768  207.633533736483  211.901117621304
# 14                ..                ..                ..                ..
# 15            33.735            34.389            35.051            35.718
# 16            49.046            47.959            47.354            46.611
# 17                ..                ..                ..                ..
# 18         445954579         456351876         467024193         477933619
# 19  83.0351017584916  85.9697041171847  90.2768688575718  101.315164901321
# 20                ..                ..                ..                ..
# 21            17.924            18.032            18.218            18.405
# 22            42.506            42.294            42.101            41.907
# 23                ..                ..                ..                ..
# 24           3298021           3408415           3521164           3635798
# 25  203.879750917293  191.907440848606  234.041924772604  258.760222652634
# 26                ..                ..                ..                ..
# 27            30.191            31.112            32.074            33.052
# 28            52.229             51.39            50.461             49.47
# 29                ..                ..                ..                ..
# 30          36268055          37439317          38683283          39982118
# 31   359.54505933555  378.212027367914  392.934591017003  424.189633551679
# 32                ..                ..                ..                ..
# 33            50.753             51.59            52.428            53.265
# 34            46.953            46.775            46.728            46.625
# 35                ..                ..                ..                ..
# 36          52400000          52800000          53250000          53650000
# 37  1397.59486332505  1472.38577733235  1525.77591825763    1613.456953048
# 38                ..                ..                ..                ..
# 39            78.444            78.374            78.237            78.099
# 40              17.5              17.9              18.3              18.5
# 41                ..                ..                ..                ..
# 42          45954226          47060915          48161841          49325050
# 43  81.5869472962009  87.5173724745356  89.4933355376524   93.883886249529
# 44                ..                ..                ..                ..
# 45            22.104            22.501            22.751            23.002
# 46            45.749             45.76            45.647            45.503
# 47                ..                ..                ..                ..
# 48          28486871          29342411          30185979          31043711
# 49  263.837059857294  278.477269278725  164.135595310797  177.331345228822
# 50                ..                ..                ..                ..
# 51            30.297            30.555            30.816            31.077
# 52             46.49            46.051            45.513            44.929
# 53                ..                ..                ..                ..
#
#                 1964              1965  ...              2013  \
# 0          698355000         715185000  ...        1363240000
# 1   85.4982461036748  98.4864217470782  ...  7020.38568208449
# 2                 ..                ..  ...              4.05
# 3             18.299            18.086  ...            53.013
# 4              39.14             37.88  ...             13.03
# 5                 ..                ..  ...              39.7
# 6          191889000         194303000  ...         316059947
# 7   3573.94118474743  3827.52710972039  ...  53291.1276891406
# 8                5.2               4.5  ...              7.37
# 9             71.508            71.879  ...            81.299
# 10              21.1              19.4  ...              12.4
# 11                ..                ..  ...              40.7
# 12          23948624          24667026  ...          78458928
# 13  224.641116847529  251.239039633033  ...  6280.68186752661
# 14                ..                ..  ...              10.6
# 15            36.391            37.068  ...            72.295
# 16            45.916            45.481  ...            19.445
# 17                ..                ..  ...              37.4
# 18         489059309         500114346  ...        1291132063
# 19  115.487608265464  119.082475942029  ...  1438.05699513067
# 20                ..                ..  ...                ..
# 21            18.595            18.785  ...            32.003
# 22            41.721            41.346  ...            19.935
# 23                ..                ..  ...                ..
# 24           3752313           3868712  ...          10157051
# 25  273.324719979383  229.559605367368  ...  6171.29506392047
# 26                ..                ..  ...              7.35
# 27            34.046            35.052  ...            76.749
# 28            48.465            47.437  ...            21.166
# 29                ..                ..  ...              47.7
# 30          41333878          42737991  ...         117290686
# 31  485.800049536121  511.020744474395  ...  10865.6872912453
# 32                ..                ..  ...              4.91
# 33              54.1            54.931  ...            78.699
# 34            46.509            46.198  ...            19.326
# 35                ..                ..  ...                ..
# 36          54000000          54348050  ...          64128273
# 37  1748.28819272053  1873.56785484264  ...  43449.0917173139
# 38                ..                ..  ...              7.52
# 39             77.96            77.821  ...            82.102
# 40              18.8              18.3  ...              12.1
# 41                ..                ..  ...              32.7
# 42          50552592          51841626  ...         205337562
# 43  102.961207229136  114.372018643314  ...  1126.04077606401
# 44                ..                ..  ...              2.95
# 45            23.256            23.511  ...            35.613
# 46            45.298            45.091  ...            31.181
# 47                ..                ..  ...              29.5
# 48          31916622          32805538  ...          99700107
# 49  186.540911391653  198.666127426693  ...  2847.56795417743
# 50                ..                ..  ...               3.5
# 51             31.34            31.604  ...            45.903
# 52            44.313             43.68  ...            24.286
# 53                ..                ..  ...                ..
#
#                 2014              2015              2016              2017  \
# 0         1371860000        1379860000        1387790000        1396215000
# 1   7636.07422276004  8016.44601585644  8094.39037512163  8817.04549566316
# 2                4.1                ..                ..               3.9
# 3             54.259              55.5            56.736             57.96
# 4              13.83             11.99             13.57             12.64
# 5               39.2              38.6              38.5              39.1
# 6          318386329         320738994         323071755         325122128
# 7   55123.8497869046  56762.7294515989  57866.7449341091   59907.754260885
# 8               6.17              5.28              4.87              4.36
# 9             81.483            81.671            81.862            82.058
# 10              12.5              12.4              12.2              11.8
# 11              41.5              41.2              41.1              41.2
# 12          79961672          81790841          83306231          84505076
# 13  5757.54333261849  4990.93679537694  5497.24323256491  5758.59072767048
# 14             10.68             11.17             12.62             12.23
# 15             72.83            73.358             73.88            74.394
# 16            19.824            19.428            19.017            18.608
# 17              38.8              39.5                40              40.8
# 18        1307246509        1322866505        1338636340        1354195680
# 19  1559.86377161811  1590.17432166504   1714.2795405846  1957.96981368095
# 20                ..                ..                ..                ..
# 21            32.384            32.777            33.182              33.6
# 22            19.049            18.765            18.514            17.911
# 23                ..              34.7              34.8              35.9
# 24          10282115          10405832          10527592          10647244
# 25  6533.67096798065   6838.9367346602  7191.06971254766  7513.49795078555
# 26              6.72              7.61              7.28              5.83
# 27             77.67            78.566            79.436            80.277
# 28            20.867            20.596            20.258            19.993
# 29              44.3              45.2              45.7              42.2
# 30         118755887         120149897         121519221         122839258
# 31  11076.1341141975  9753.40056232226  8875.08206876137  9434.37817948243
# 32              4.81              4.31              3.85              3.42
# 33            78.993            79.285            79.577            79.867
# 34            18.711            17.968             17.42            16.947
# 35              48.7                ..              47.7                ..
# 36          64602298          65116219          65611593          66058859
# 37  47447.5889322667  45071.0743234873  41146.0773555246  40622.6893883232
# 38              6.11               5.3              4.81              4.33
# 39            82.365            82.626            82.886            83.143
# 40                12              11.9              11.8              11.4
# 41              33.1              33.3              33.1              32.6
# 42         208251628         210969298         213524840         216379655
# 43  1173.39230924409  1282.44302583998  1468.82207690892  1567.64061969895
# 44              1.83              3.57                ..                ..
# 45            35.819            36.026            36.234            36.442
# 46            30.462            29.699            29.306            28.963
# 47                ..              31.3                ..                ..
# 48         101325201         103031365         104875266         106738501
# 49   2935.9285781194  2974.29692047629  3038.15204593606  3077.43443152814
# 50               3.6              3.07               2.7              2.55
# 51            46.093            46.284            46.475            46.682
# 52            23.827            23.252            22.836            22.664
# 53                ..              44.6                ..                ..
#
#             2018              2019              2020              2021  \
# 0   1.402760e+09        1407745000        1411100000        1412360000
# 1   9.905406e+03  10143.8602060373  10408.7191247747  12617.5049863004
# 2   4.930000e+00              5.15              5.61              5.11
# 3   5.915200e+01            60.308            61.428            62.512
# 4   1.086000e+01             10.41              8.52              7.52
# 5   3.850000e+01              38.2                ..                ..
# 6   3.268382e+08         328329953         331511512         332031554
# 7   6.282331e+04  65120.3946628653  63528.6343027508   70219.472454115
# 8   3.900000e+00              3.67              8.05              5.35
# 9   8.225600e+01            82.459            82.664            82.873
# 10  1.160000e+01              11.4              10.9                11
# 11  4.140000e+01              41.5              39.7                ..
# 12  8.561756e+07          86564202          87290193          87923432
# 13  3.829830e+03  3276.75326508099  2746.41948317956  4084.20030479458
# 14  1.219000e+01             10.74              9.69              9.28
# 15  7.489800e+01            75.391            75.874            76.345
# 16  1.723100e+01            15.118            14.231            13.699
# 17  4.200000e+01              40.9                ..                ..
# 18  1.369003e+09        1383112050        1396387127        1407563842
# 19  1.974378e+03  2050.16378973235  1913.21972103493  2238.12713873311
# 20  7.650000e+00              6.51              7.86              6.38
# 21  3.403000e+01            34.472            34.926            35.393
# 22  1.765100e+01            17.049            16.572            16.419
# 23  3.460000e+01              35.7                ..                ..
# 24  1.076553e+07          10881882          10999664          11117873
# 25  7.947159e+03  8173.34464573914  7167.91493205787   8476.7496882797
# 26  5.860000e+00              6.18              6.13               7.7
# 27  8.107400e+01            81.828             82.54            83.213
# 28  1.976200e+01            19.291             18.78            18.432
# 29  4.370000e+01              41.9              39.6              38.5
# 30  1.240139e+08         125085311         125998302         126705138
# 31  9.857007e+03  10145.1526279593  8654.99732516958   10045.676371041
# 32  3.270000e+00              3.48              4.44              4.09
# 33  8.015600e+01            80.444            80.731            81.016
# 34  1.646500e+01             15.71            15.565            14.857
# 35  4.670000e+01                ..              45.4                ..
# 36  6.646034e+07          66836327          67081234          67026300
# 37  4.330631e+04   42747.080460496  40318.4169225055  46585.8975644567
# 38  4.000000e+00              3.74                ..                ..
# 39  8.339800e+01            83.652            83.903            84.152
# 40  1.100000e+01              10.7              10.1              10.1
# 41  3.370000e+01              32.8              32.6                ..
# 42  2.197315e+08         223293280         227196741         231402117
# 43  1.620743e+03   1437.1658337701  1322.31478270271  1505.01019279459
# 44  4.080000e+00              4.83                ..              6.34
# 45  3.666600e+01            36.907            37.165             37.44
# 46  2.859400e+01            28.276            27.967            27.519
# 47  2.960000e+01                ..                ..                ..
# 48  1.085688e+08         110380804         112190977         113880328
# 49  3.194673e+03   3413.8490672059   3224.4228110466  3460.53940077621
# 50  2.340000e+00              2.24              2.52               3.4
# 51  4.690700e+01            47.149            47.408            47.684
# 52  2.244500e+01            22.254            22.039            21.813
# 53  4.230000e+01                ..                ..              40.7
#
#                 2022
# 0         1412175000
# 1   12720.2156397612
# 2                 ..
# 3              63.56
# 4                 ..
# 5                 ..
# 6          333287557
# 7   76398.5917422054
# 8               3.65
# 9             83.084
# 10                ..
# 11                ..
# 12          88550570
# 13  4387.82571517872
# 14                ..
# 15            76.807
# 16                ..
# 17                ..
# 18        1417173173
# 19  2388.62119776762
# 20              4.82
# 21            35.872
# 22                ..
# 23                ..
# 24          11228821
# 25  10120.5511632969
# 26                ..
# 27            83.848
# 28                ..
# 29                ..
# 30         127504125
# 31  11091.3054302538
# 32              3.26
# 33              81.3
# 34                ..
# 35                ..
# 36          66971411
# 37  45850.4261222629
# 38                ..
# 39            84.398
# 40                ..
# 41                ..
# 42         235824862
# 43  1596.66266149236
# 44                ..
# 45            37.731
# 46                ..
# 47                ..
# 48         115559009
# 49  3498.50981598253
# 50                ..
# 51            47.977
# 52                ..
# 53                ..
#
# [54 rows x 67 columns]

# %%
# Get rid the unnecessary columns
countries_regressors_raw = df_filtered.drop(columns= {"Country Code", "Series Code"} )
countries_regressors_raw.head()
# Out:
#   Country Name       Series Name              1960              1961  \
# 0        China  Population_total         667070000         660330000
# 1        China    GDP_per_capita  89.5202179159242  75.8055639067957
# 2        China                UR                ..                ..
# 3        China  Urban_population            16.203            16.708
# 4        China  Birth_rate_crude             20.86             18.02
#
#                1962              1963              1964              1965  \
# 0         665770000         682335000         698355000         715185000
# 1  70.9091553472599  74.3133748233246  85.4982461036748  98.4864217470782
# 2                ..                ..                ..                ..
# 3            17.226            17.757            18.299            18.086
# 4             37.01             43.37             39.14             37.88
#
#                1966            1967  ...              2013              2014  \
# 0         735400000       754550000  ...        1363240000        1371860000
# 1  104.324189073855  96.58918279471  ...  7020.38568208449  7636.07422276004
# 2                ..              ..  ...              4.05               4.1
# 3            17.915          17.785  ...            53.013            54.259
# 4             35.05           33.96  ...             13.03             13.83
#
#                2015              2016              2017          2018  \
# 0        1379860000        1387790000        1396215000  1.402760e+09
# 1  8016.44601585644  8094.39037512163  8817.04549566316  9.905406e+03
# 2                ..                ..               3.9  4.930000e+00
# 3              55.5            56.736             57.96  5.915200e+01
# 4             11.99             13.57             12.64  1.086000e+01
#
#                2019              2020              2021              2022
# 0        1407745000        1411100000        1412360000        1412175000
# 1  10143.8602060373  10408.7191247747  12617.5049863004  12720.2156397612
# 2              5.15              5.61              5.11                ..
# 3            60.308            61.428            62.512             63.56
# 4             10.41              8.52              7.52                ..
#
# [5 rows x 65 columns]

# %%
#countries_regressors_raw.info()

# %% [markdown]
# ### Cleaning US state regressors

# %%
variables_by_state_raw = pd.read_csv("Resources/variable 2011-2021.csv")
variables_by_state_rename = variables_by_state_raw.rename(columns={"Unemployeement Rate": "UR_STATE",
                                                                  "GDP Per Capita":"GDP_per_capita_state", "Birth Rate":"Bith_rate_state"  })

# Multiply the "unemployment rate" column by 10
variables_by_state_rename["UR_STATE"] *= 10

# %% [markdown]
# ## Cleaning inmigration csv

# %%
migration = inmigration.rename(columns={"Region and country of birth": "Country_origin", "Total Permanent Residents": "Total_inmigrants"})
migration = migration[migration["Country_origin"]!= "Total"]
migration = migration.drop(columns="Percentage")
migration["Country_origin"] = migration["Country_origin"].replace("China, People's Republic", "China")
migration
# Out:
#      Year      Country_origin  Total_inmigrants  Alabama  Alaska  Arizona  \
# 1    2005               China             69967      328      92      543
# 2    2005  Dominican Republic             27504        5      42       22
# 3    2005               India             84681      431      15      739
# 4    2005                Iran             13887       48       4      285
# 5    2005              Mexico            161445      569      96     8373
# ..    ...                 ...               ...      ...     ...      ...
# 148  2021                Iran              5734       21       0       86
# 149  2021              Mexico            107230      323      33     6859
# 150  2021            Pakistan              9691       31       0       59
# 151  2021         Philippines             27511      152     190      555
# 152  2021      United Kingdom              9229       48      13      179
#
#      Arkansas  California  Colorado  Connecticut  ...  Virginia  Washington  \
# 1         202       17668       765          894  ...      1327        1508
# 2           0          82         6          319  ...        90          18
# 3         215       14724       516         1571  ...      2776        1747
# 4           9        7059       131           88  ...       562         318
# 5         870       63092      2891          316  ...       870        2330
# ..        ...         ...       ...          ...  ...       ...         ...
# 148        17        2206        89           39  ...       218         187
# 149       610       31715      3131          247  ...       586        2539
# 150        41        1104        52          111  ...       784         166
# 151       129        6478       228          178  ...       648         737
# 152        59        1651       146          205  ...       237         309
#
#      West Virginia  Wisconsin  Wyoming  U.S. Armed Services posts  \
# 1              101        593       28                         13
# 2                6         39        0                          0
# 3              133        876        0                          0
# 4               18         48        0                          0
# 5               30       1054       75                          0
# ..             ...        ...      ...                        ...
# 148              9         38        0                          0
# 149             20        949       69                          0
# 150             17         57        3                          0
# 151             69        236       27                          0
# 152             14         72        8                          0
#
#      U.S. possessions  U.S. Dependencies  Guam  Puerto Rico
# 1                 184                  0     0            0
# 2                2346                  0     0            0
# 3                  24                  0     0            0
# 4                   0                  0     0            0
# 5                 129                  0     0            0
# ..                ...                ...   ...          ...
# 148                 0                  0     0            0
# 149                 0                  0     0           39
# 150                 0                  0     0            0
# 151                 0                  0   300            9
# 152                 0                  0     0            0
#
# [136 rows x 59 columns]

# %% [markdown]
# ### Create a Database and store the cleaned dataset

# %%
# Create database with the desired file name for your SQLite database
conn = sqlite3.connect('use_migration.db')

# Store DatFrames in the database
migration.to_sql('migration', conn, index=False,  if_exists='replace')
countries_regressors_raw.to_sql('countries_regressors_raw', conn, index=False,  if_exists='replace')
variables_by_state_rename.to_sql('variables_by_state_rename', conn, index=False,  if_exists='replace')
conn.close()

# %%
## Check if the DataFrames have been successfully stored in the SQLite database

# Connect to the SQLite database
conn = sqlite3.connect('use_migration.db')

# Read the data from the database
query = "SELECT * FROM migration;"
df_migration = pd.read_sql_query(query, conn)

query = "SELECT * FROM countries_regressors_raw;"
df_countries_regressors_raw = pd.read_sql_query(query, conn)

query = "SELECT * FROM variables_by_state_rename;"
df_variables_by_state_rename = pd.read_sql_query(query, conn)

# Check the data
#print("Data from migration:")
#print(df_migration)

#print("\nData from countries_regressors_raw:")
#print(df_countries_regressors_raw)

#print("\nData from variables_by_state_rename:")
#print(df_variables_by_state_rename)

# Close the database connection
#conn.close()

# %% [markdown]
# ### Linear Regression adding regressors

# %%
country_names=['China', 'India',
       'Dominican Republic', 'Mexico', 'United Kingdom', 'Pakistan',
       'Philippines']


state_names=['Alabama', 'Alaska',
       'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut',
       'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
       'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
       'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
       'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
       'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
       'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
       'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
       'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
       'West Virginia', 'Wisconsin', 'Wyoming']


results_df = pd.DataFrame(columns=['Country', 'State', 'MAE', 'MAPE','pred2023'])
# DataFrame to store predictions
df_predictions = pd.DataFrame()
df_scores = pd.DataFrame()
# Collect all predictions and true values for final R-squared calculation
all_preds = []
all_true = []

for country in country_names:
    
    # Filter by country
    regressor_by_country = df_countries_regressors_raw.loc[countries_regressors_raw["Country Name"]== country]
    # Drop the Country Name column
    drop_countryname = regressor_by_country.drop(columns="Country Name")
    # Transpose rows per columns
    regressor_by_country_not_cleaned = drop_countryname.transpose()
    # Use the first row as the column names
    regressor_by_country_not_cleaned.columns = regressor_by_country_not_cleaned.iloc[0]
    # Drop the first row (previous integer index) since it's now redundant
    regressor_by_country_drop_row = regressor_by_country_not_cleaned.iloc[1:]
    print(country)
    regressor_by_country_reset_index = regressor_by_country_drop_row.reset_index().rename(columns={"index":"Year"})
    #display(regressor_by_country_reset_index)
    regressor_by_country_reset_index["Year"] = regressor_by_country_reset_index["Year"].astype(int)
    regressor_by_country_reset_index["Population_total"] = regressor_by_country_reset_index["Population_total"].astype(int)
    regressor_by_country_reset_index["GDP_per_capita"] = regressor_by_country_reset_index["GDP_per_capita"].astype(float)
    regressor_by_country_reset_index['UR'].replace('..', np.nan, inplace=True)
    regressor_by_country_reset_index["UR"] = regressor_by_country_reset_index["UR"].astype(float)
    regressor_by_country_reset_index["Urban_population"] = regressor_by_country_reset_index["Urban_population"].astype(float)
    regressor_by_country_reset_index['Birth_rate_crude'].replace('..', np.nan, inplace=True)
    regressor_by_country_reset_index["Birth_rate_crude"] = regressor_by_country_reset_index["Birth_rate_crude"].astype(float)
    regressor_by_country_reset_index['Gini_index'].replace('..', np.nan, inplace=True)
    regressor_by_country_reset_index["Gini_index"] = regressor_by_country_reset_index["Gini_index"].astype(float)
    regressor_by_country = regressor_by_country_reset_index
    
    
    for state in state_names:



        # Getting the DataFrame with the years, total number of inmigrants in the US for a given country and 
        # the number of inmigrants of this country in one US state
        migration.reset_index(drop=True, inplace=True)
        county_origin_us_df = df_migration[migration["Country_origin"]==country]
        country_columns = ["Year","Total_inmigrants",state]
        inmigration_us_df = county_origin_us_df[country_columns]
        print(state)

        #Filter by state
        state_test = df_variables_by_state_rename[variables_by_state_rename["State"]==state]
        regressor_by_state = state_test.drop(columns= "State").reset_index(drop=True)
    
        # First merge inmigration_us_df and regressor_by_country
        df_merged1 = pd.merge(inmigration_us_df, regressor_by_country, on="Year", how="left")

        # Then merge the result with regressor_by_state
        df_merged = pd.merge(df_merged1, regressor_by_state, on="Year", how="left")

        
        # LINEAR REGRESSION
        
        # Handle NaN values in the DataFrame
        # For simplicity, we'll fill the NaN values with the column means
        df_merged = pd.merge(df_merged1, regressor_by_state, on="Year", how="left")
        def set_covid(row):
            if row["Year"] in [2020, 2021]:
                return 1
            else:
                return 0

        # Add the Covid column using the apply method
        df_merged["Covid"] = df_merged.apply(set_covid, axis=1)
        df_merged.fillna(df_merged.mean(), inplace=True)

        # Prepare the state-specific data, excluding the year 2019
        cols_to_scale = ['Year', 'Population_total', 'GDP_per_capita', 'Urban_population',
                         'Birth_rate_crude', 'Gini_index', 'GDP_per_capita_state', 'UR_STATE', 'Covid']
        X = df_merged[cols_to_scale]  # Features
        y = df_merged[state].values  # Target for the specific state

        # Exclude the year 2019 from the training data
        X_train, y_train = X[X['Year'] != 2019], y[X['Year'] != 2019]
        X_test = X[X['Year'] == 2019]  # Keep the data for the year 2019 for prediction

        # Create a min-max scaler object and apply normalization for training data
        scaler = MinMaxScaler()
        X_train_scaled = scaler.fit_transform(X_train.drop(columns=['Year']))  # Exclude 'Year' column
        
        

        # Normalize X_test for prediction using the same scaler (handle NaN values)
        X_test_scaled = scaler.transform(X_test.drop(columns=['Year']))
        # Create and train the model
        model = LinearRegression()
        model.fit(X_train_scaled, y_train)

        # Check if there are NaN values in the test data before making predictions
        if np.isnan(X_test_scaled).any():
            # Handle NaN values in X_test_scaled using SimpleImputer
            imputer = SimpleImputer(strategy='mean')
            X_test_scaled = imputer.fit_transform(X_test_scaled)
            
        X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.drop(columns=['Year']).columns)

        print(X_test_scaled_df)

        # Calculate predicted values for the year 2019
        y_pred = model.predict(X_test_scaled)[0]
        
        # Get the true target value for the year 2019 for the specific state
        y_true = df_merged[df_merged['Year'] == 2019][state].values

        # Append predicted and true values to the respective lists
        all_preds.append(y_pred)
        all_true.extend(y_true)

        # Calculate R2 score, RMSE, and MAPE
        from sklearn.metrics import mean_absolute_error
        y_true = df_merged[state][-3:-2].values
        print("2019- Real data for " + country + " " + state + ":" + str(y_true))
        print("2019- Predicted for " + country + " " + state + ": " + str(y_pred))
        mae = mean_absolute_error(y_true, [y_pred])  # Convert y_pred to a one-element array
        print("The MAE while testing 2019 for " + country + " " + state + ": " + str(mae))
        mape = mean_absolute_percentage_error(y_true, [y_pred])  # Convert y_pred to a one-element array
        print("The MAPE while testing 2019 for " + country + " " + state + ": " + str(mape))
        overall_r2 = r2_score(y_true, [y_pred])  # Convert y_pred to a one-element array
        mse = mean_squared_error(y_true, [y_pred])  # Convert y_pred to a one-element array
        rmse = np.sqrt(mse)
        medae = median_absolute_error(y_true, [y_pred])  # Convert y_pred to a one-element array
        cvrmse = (rmse / y_true.mean()) * 100

        # Store scores in the scores DataFrame
        df_scores = df_scores.append({
            'Country': country,
            'State': state,
            'R2 Score': overall_r2,
            'RMSE': rmse,
            'MAPE': mape,
            'MEDAE': medae,
            'CVRMSE': cvrmse,
            'data2019': y_true,
            'pred2019': y_pred,
        }, ignore_index=True)
# Out:
# China
# Alabama
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.558951 -0.030585    0.0
# 2019- Real data for China Alabama:[154]
# 2019- Predicted for China Alabama: 114.47124424572351
# The MAE while testing 2019 for China Alabama: 39.52875575427649
# The MAPE while testing 2019 for China Alabama: 0.2566802321706266
# Alaska
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.454474 -0.196519    0.0
# 2019- Real data for China Alaska:[33]
# 2019- Predicted for China Alaska: 35.23272882214144
# The MAE while testing 2019 for China Alaska: 2.232728822141439
# The MAPE while testing 2019 for China Alaska: 0.06765844915580119
# Arizona
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.678893  0.000678    0.0
# 2019- Real data for China Arizona:[498]
# 2019- Predicted for China Arizona: 385.2686762318395
# The MAE while testing 2019 for China Arizona: 112.73132376816051
# The MAPE while testing 2019 for China Arizona: 0.22636812001638656
# Arkansas
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.554523   -0.0379    0.0
# 2019- Real data for China Arkansas:[88]
# 2019- Predicted for China Arkansas: 75.11560442522608
# The MAE while testing 2019 for China Arkansas: 12.884395574773919
# The MAPE while testing 2019 for China Arkansas: 0.14641358607697635
# California
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.722713 -0.021554    0.0
# 2019- Real data for China California:[21604]
# 2019- Predicted for China California: 19684.871490660647
# The MAE while testing 2019 for China California: 1919.1285093393526
# The MAPE while testing 2019 for China California: 0.08883209171169008
# Colorado
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.844823  0.008614    0.0
# 2019- Real data for China Colorado:[516]
# 2019- Predicted for China Colorado: 172.2291322949668
# The MAE while testing 2019 for China Colorado: 343.7708677050332
# The MAPE while testing 2019 for China Colorado: 0.6662226118314597
# Connecticut
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.621331 -0.054482    0.0
# 2019- Real data for China Connecticut:[393]
# 2019- Predicted for China Connecticut: 343.2120573558988
# The MAE while testing 2019 for China Connecticut: 49.78794264410118
# The MAPE while testing 2019 for China Connecticut: 0.12668687695700045
# Delaware
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.308942 -0.029759    0.0
# 2019- Real data for China Delaware:[148]
# 2019- Predicted for China Delaware: 106.98195148866714
# The MAE while testing 2019 for China Delaware: 41.018048511332864
# The MAPE while testing 2019 for China Delaware: 0.27714897642792474
# District of Columbia
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.316791 -0.043685    0.0
# 2019- Real data for China District of Columbia:[87]
# 2019- Predicted for China District of Columbia: 115.31708682951793
# The MAE while testing 2019 for China District of Columbia: 28.317086829517933
# The MAPE while testing 2019 for China District of Columbia: 0.32548375666112567
# Florida
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.654161 -0.063128    0.0
# 2019- Real data for China Florida:[1717]
# 2019- Predicted for China Florida: 1623.1317123987237
# The MAE while testing 2019 for China Florida: 93.86828760127628
# The MAPE while testing 2019 for China Florida: 0.054669940361838254
# Georgia
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.829463 -0.052869    0.0
# 2019- Real data for China Georgia:[982]
# 2019- Predicted for China Georgia: 993.7429741155355
# The MAE while testing 2019 for China Georgia: 11.742974115535503
# The MAPE while testing 2019 for China Georgia: 0.011958222113579942
# Hawaii
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              1.009757  0.033142    0.0
# 2019- Real data for China Hawaii:[589]
# 2019- Predicted for China Hawaii: 349.7712839495357
# The MAE while testing 2019 for China Hawaii: 239.2287160504643
# The MAPE while testing 2019 for China Hawaii: 0.4061608082350837
# Idaho
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.720462 -0.001016    0.0
# 2019- Real data for China Idaho:[116]
# 2019- Predicted for China Idaho: 94.4326899892768
# The MAE while testing 2019 for China Idaho: 21.567310010723205
# The MAPE while testing 2019 for China Idaho: 0.18592508629933796
# Illinois
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.719203 -0.077262    0.0
# 2019- Real data for China Illinois:[1972]
# 2019- Predicted for China Illinois: 1643.1008573385307
# The MAE while testing 2019 for China Illinois: 328.89914266146934
# The MAPE while testing 2019 for China Illinois: 0.16678455510216497
# Indiana
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.586057 -0.022882    0.0
# 2019- Real data for China Indiana:[380]
# 2019- Predicted for China Indiana: 415.6770249773421
# The MAE while testing 2019 for China Indiana: 35.677024977342114
# The MAPE while testing 2019 for China Indiana: 0.09388690783511083
# Iowa
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.557809  0.027963    0.0
# 2019- Real data for China Iowa:[170]
# 2019- Predicted for China Iowa: 122.74115090576873
# The MAE while testing 2019 for China Iowa: 47.258849094231266
# The MAPE while testing 2019 for China Iowa: 0.2779932299660663
# Kansas
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.873452 -0.011821    0.0
# 2019- Real data for China Kansas:[168]
# 2019- Predicted for China Kansas: 193.59171810793555
# The MAE while testing 2019 for China Kansas: 25.59171810793555
# The MAPE while testing 2019 for China Kansas: 0.15233165540437826
# Kentucky
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.649943 -0.022248    0.0
# 2019- Real data for China Kentucky:[154]
# 2019- Predicted for China Kentucky: 157.473176268352
# The MAE while testing 2019 for China Kentucky: 3.473176268352006
# The MAPE while testing 2019 for China Kentucky: 0.0225530926516364
# Louisiana
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.948093 -0.055162    0.0
# 2019- Real data for China Louisiana:[183]
# 2019- Predicted for China Louisiana: 202.35116258834043
# The MAE while testing 2019 for China Louisiana: 19.35116258834043
# The MAPE while testing 2019 for China Louisiana: 0.10574405785978376
# Maine
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.564303 -0.056177    0.0
# 2019- Real data for China Maine:[47]
# 2019- Predicted for China Maine: 64.5877285722064
# The MAE while testing 2019 for China Maine: 17.5877285722064
# The MAPE while testing 2019 for China Maine: 0.3742069908980085
# Maryland
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.401869 -0.121312    0.0
# 2019- Real data for China Maryland:[1137]
# 2019- Predicted for China Maryland: 878.9896171537232
# The MAE while testing 2019 for China Maryland: 258.0103828462768
# The MAPE while testing 2019 for China Maryland: 0.22692206055081512
# Massachusetts
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.516589  -0.07749    0.0
# 2019- Real data for China Massachusetts:[2121]
# 2019- Predicted for China Massachusetts: 1914.9009035620409
# The MAE while testing 2019 for China Massachusetts: 206.09909643795913
# The MAPE while testing 2019 for China Massachusetts: 0.0971707196784343
# Michigan
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.420555 -0.016274    0.0
# 2019- Real data for China Michigan:[763]
# 2019- Predicted for China Michigan: 504.57504852138817
# The MAE while testing 2019 for China Michigan: 258.42495147861183
# The MAPE while testing 2019 for China Michigan: 0.33869587349752533
# Minnesota
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.697442  0.064042    0.0
# 2019- Real data for China Minnesota:[476]
# 2019- Predicted for China Minnesota: 415.660127132047
# The MAE while testing 2019 for China Minnesota: 60.33987286795298
# The MAPE while testing 2019 for China Minnesota: 0.12676443879822055
# Mississippi
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.586035  0.115271    0.0
# 2019- Real data for China Mississippi:[78]
# 2019- Predicted for China Mississippi: 99.94088247566202
# The MAE while testing 2019 for China Mississippi: 21.940882475662022
# The MAPE while testing 2019 for China Mississippi: 0.28129336507259
# Missouri
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.713126 -0.005641    0.0
# 2019- Real data for China Missouri:[362]
# 2019- Predicted for China Missouri: 315.1428606154216
# The MAE while testing 2019 for China Missouri: 46.857139384578375
# The MAPE while testing 2019 for China Missouri: 0.12943961155960876
# Montana
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.489755   0.03683    0.0
# 2019- Real data for China Montana:[25]
# 2019- Predicted for China Montana: 60.63899147944208
# The MAE while testing 2019 for China Montana: 35.63899147944208
# The MAPE while testing 2019 for China Montana: 1.4255596591776833
# Nebraska
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.760205  0.253634    0.0
# 2019- Real data for China Nebraska:[101]
# 2019- Predicted for China Nebraska: 128.4977839096519
# The MAE while testing 2019 for China Nebraska: 27.4977839096519
# The MAPE while testing 2019 for China Nebraska: 0.2722552862341772
# Nevada
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.584609 -0.029416    0.0
# 2019- Real data for China Nevada:[669]
# 2019- Predicted for China Nevada: 570.5741195591859
# The MAE while testing 2019 for China Nevada: 98.42588044081413
# The MAPE while testing 2019 for China Nevada: 0.14712388705652335
# New Hampshire
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.374779 -0.015151    0.0
# 2019- Real data for China New Hampshire:[76]
# 2019- Predicted for China New Hampshire: 57.56898769310986
# The MAE while testing 2019 for China New Hampshire: 18.43101230689014
# The MAPE while testing 2019 for China New Hampshire: 0.24251331982750182
# New Jersey
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.797134 -0.102523    0.0
# 2019- Real data for China New Jersey:[1952]
# 2019- Predicted for China New Jersey: 2119.595935454765
# The MAE while testing 2019 for China New Jersey: 167.5959354547649
# The MAPE while testing 2019 for China New Jersey: 0.08585857349117056
# New Mexico
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.991823  0.009677    0.0
# 2019- Real data for China New Mexico:[84]
# 2019- Predicted for China New Mexico: 88.25233382265662
# The MAE while testing 2019 for China New Mexico: 4.252333822656624
# The MAPE while testing 2019 for China New Mexico: 0.05062302169829314
# New York
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.745308 -0.043065    0.0
# 2019- Real data for China New York:[12758]
# 2019- Predicted for China New York: 14987.601383806503
# The MAE while testing 2019 for China New York: 2229.601383806503
# The MAPE while testing 2019 for China New York: 0.17476104278150986
# North Carolina
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692               0.55725 -0.023372    0.0
# 2019- Real data for China North Carolina:[682]
# 2019- Predicted for China North Carolina: 747.5256322251041
# The MAE while testing 2019 for China North Carolina: 65.52563222510412
# The MAPE while testing 2019 for China North Carolina: 0.09607863962625238
# North Dakota
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.847924 -0.089958    0.0
# 2019- Real data for China North Dakota:[37]
# 2019- Predicted for China North Dakota: 35.777204111624236
# The MAE while testing 2019 for China North Dakota: 1.2227958883757637
# The MAPE while testing 2019 for China North Dakota: 0.03304853752366929
# Ohio
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692               0.65761 -0.075245    0.0
# 2019- Real data for China Ohio:[753]
# 2019- Predicted for China Ohio: 643.4042383172857
# The MAE while testing 2019 for China Ohio: 109.59576168271428
# The MAPE while testing 2019 for China Ohio: 0.14554550024264845
# Oklahoma
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              1.108989 -0.052798    0.0
# 2019- Real data for China Oklahoma:[174]
# 2019- Predicted for China Oklahoma: 179.7869183539466
# The MAE while testing 2019 for China Oklahoma: 5.786918353946589
# The MAPE while testing 2019 for China Oklahoma: 0.033258151459463155
# Oregon
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.933649 -0.053906    0.0
# 2019- Real data for China Oregon:[598]
# 2019- Predicted for China Oregon: 469.2104589541642
# The MAE while testing 2019 for China Oregon: 128.7895410458358
# The MAPE while testing 2019 for China Oregon: 0.21536712549470868
# Pennsylvania
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.860441 -0.021307    0.0
# 2019- Real data for China Pennsylvania:[1498]
# 2019- Predicted for China Pennsylvania: 1522.9248742276177
# The MAE while testing 2019 for China Pennsylvania: 24.924874227617693
# The MAPE while testing 2019 for China Pennsylvania: 0.016638767842201398
# Rhode Island
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.504079 -0.073223    0.0
# 2019- Real data for China Rhode Island:[95]
# 2019- Predicted for China Rhode Island: 72.06251113494537
# The MAE while testing 2019 for China Rhode Island: 22.937488865054632
# The MAPE while testing 2019 for China Rhode Island: 0.2414472512111014
# South Carolina
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.838653 -0.083097    0.0
# 2019- Real data for China South Carolina:[138]
# 2019- Predicted for China South Carolina: 221.1765408202477
# The MAE while testing 2019 for China South Carolina: 83.17654082024771
# The MAPE while testing 2019 for China South Carolina: 0.6027285566684617
# South Dakota
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.436798  0.071076    0.0
# 2019- Real data for China South Dakota:[26]
# 2019- Predicted for China South Dakota: 25.80758590134377
# The MAE while testing 2019 for China South Dakota: 0.19241409865622927
# The MAPE while testing 2019 for China South Dakota: 0.007400542256008818
# Tennessee
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.609741 -0.025517    0.0
# 2019- Real data for China Tennessee:[328]
# 2019- Predicted for China Tennessee: 310.36660979964427
# The MAE while testing 2019 for China Tennessee: 17.633390200355734
# The MAPE while testing 2019 for China Tennessee: 0.05376033597669431
# Texas
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              1.055088  -0.09251    0.0
# 2019- Real data for China Texas:[3053]
# 2019- Predicted for China Texas: 2776.988500242688
# The MAE while testing 2019 for China Texas: 276.01149975731187
# The MAPE while testing 2019 for China Texas: 0.09040664911801895
# Utah
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.708537 -0.046799    0.0
# 2019- Real data for China Utah:[234]
# 2019- Predicted for China Utah: 202.0112349921364
# The MAE while testing 2019 for China Utah: 31.988765007863606
# The MAPE while testing 2019 for China Utah: 0.13670412396522907
# Vermont
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.365566 -0.116703    0.0
# 2019- Real data for China Vermont:[0]
# 2019- Predicted for China Vermont: 14.175820980149055
# The MAE while testing 2019 for China Vermont: 14.175820980149055
# The MAPE while testing 2019 for China Vermont: 6.384222208387014e+16
# Virginia
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.494006 -0.070543    0.0
# 2019- Real data for China Virginia:[1035]
# 2019- Predicted for China Virginia: 1041.3600500580417
# The MAE while testing 2019 for China Virginia: 6.360050058041679
# The MAPE while testing 2019 for China Virginia: 0.006144975901489545
# Washington
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.655591 -0.048182    0.0
# 2019- Real data for China Washington:[2367]
# 2019- Predicted for China Washington: 2293.64498360475
# The MAE while testing 2019 for China Washington: 73.35501639525
# The MAPE while testing 2019 for China Washington: 0.030990712461026616
# West Virginia
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.824777 -0.054428    0.0
# 2019- Real data for China West Virginia:[54]
# 2019- Predicted for China West Virginia: 42.61822452558477
# The MAE while testing 2019 for China West Virginia: 11.381775474415228
# The MAPE while testing 2019 for China West Virginia: 0.2107736198965783
# Wisconsin
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.875416  0.042241    0.0
# 2019- Real data for China Wisconsin:[395]
# 2019- Predicted for China Wisconsin: 327.34936090457234
# The MAE while testing 2019 for China Wisconsin: 67.65063909542766
# The MAPE while testing 2019 for China Wisconsin: 0.17126744074791814
# Wyoming
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0           0.95752         0.77231          0.889745          0.409929
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0   -0.057692              0.721152 -0.159071    0.0
# 2019- Real data for China Wyoming:[19]
# 2019- Predicted for China Wyoming: 42.912404383351344
# The MAE while testing 2019 for China Wyoming: 23.912404383351344
# The MAPE while testing 2019 for China Wyoming: 1.258547599123755
# India
# Alabama
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.903324        0.876957          0.850438          0.083765
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0    0.846154              0.558951 -0.030585    0.0
# 2019- Real data for India Alabama:[339]
# 2019- Predicted for India Alabama: 363.7651935168502
# The MAE while testing 2019 for India Alabama: 24.765193516850218
# The MAPE while testing 2019 for India Alabama: 0.07305366819129858
# Alaska
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.903324        0.876957          0.850438          0.083765
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0    0.846154              0.454474 -0.196519    0.0
# 2019- Real data for India Alaska:[12]
# 2019- Predicted for India Alaska: 13.71763709864075
# The MAE while testing 2019 for India Alaska: 1.7176370986407505
# The MAPE while testing 2019 for India Alaska: 0.1431364248867292
# Arizona
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.903324        0.876957          0.850438          0.083765
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0    0.846154              0.678893  0.000678    0.0
# 2019- Real data for India Arizona:[667]
# 2019- Predicted for India Arizona: 686.2769769304548
# The MAE while testing 2019 for India Arizona: 19.276976930454794
# The MAPE while testing 2019 for India Arizona: 0.028901014888238073
# Arkansas
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.903324        0.876957          0.850438          0.083765
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0    0.846154              0.554523   -0.0379    0.0
# 2019- Real data for India Arkansas:[162]
# 2019- Predicted for India Arkansas: 267.5419889197336
# The MAE while testing 2019 for India Arkansas: 105.54198891973363
# The MAPE while testing 2019 for India Arkansas: 0.6514937587637878
# California
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:148: RuntimeWarning: divide by zero encountered in double_scalars
#   cvrmse = (rmse / y_true.mean()) * 100
# ...
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6               0.65761 -0.075245    0.0
# 2019- Real data for Philippines Ohio:[1298]
# 2019- Predicted for Philippines Ohio: 1226.5350983062235
# The MAE while testing 2019 for Philippines Ohio: 71.46490169377648
# The MAPE while testing 2019 for Philippines Ohio: 0.055057705465159076
# Oklahoma
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              1.108989 -0.052798    0.0
# 2019- Real data for Philippines Oklahoma:[192]
# 2019- Predicted for Philippines Oklahoma: 253.6543764282087
# The MAE while testing 2019 for Philippines Oklahoma: 61.65437642820871
# The MAPE while testing 2019 for Philippines Oklahoma: 0.32111654389692035
# Oregon
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.933649 -0.053906    0.0
# 2019- Real data for Philippines Oregon:[363]
# 2019- Predicted for Philippines Oregon: 374.9273646771106
# The MAE while testing 2019 for Philippines Oregon: 11.927364677110575
# The MAPE while testing 2019 for Philippines Oregon: 0.03285775393143409
# Pennsylvania
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.860441 -0.021307    0.0
# 2019- Real data for Philippines Pennsylvania:[597]
# 2019- Predicted for Philippines Pennsylvania: 538.0562183970154
# The MAE while testing 2019 for Philippines Pennsylvania: 58.943781602984586
# The MAPE while testing 2019 for Philippines Pennsylvania: 0.09873330251756213
# Rhode Island
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.504079 -0.073223    0.0
# 2019- Real data for Philippines Rhode Island:[55]
# 2019- Predicted for Philippines Rhode Island: 49.995800247723395
# The MAE while testing 2019 for Philippines Rhode Island: 5.004199752276605
# The MAPE while testing 2019 for Philippines Rhode Island: 0.09098545004139283
# South Carolina
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.838653 -0.083097    0.0
# 2019- Real data for Philippines South Carolina:[282]
# 2019- Predicted for Philippines South Carolina: 250.28599818984839
# The MAE while testing 2019 for Philippines South Carolina: 31.714001810151615
# The MAPE while testing 2019 for Philippines South Carolina: 0.11246099932677878
# South Dakota
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.436798  0.071076    0.0
# 2019- Real data for Philippines South Dakota:[47]
# 2019- Predicted for Philippines South Dakota: 46.229243023303255
# The MAE while testing 2019 for Philippines South Dakota: 0.7707569766967453
# The MAPE while testing 2019 for Philippines South Dakota: 0.016399084610569048
# Tennessee
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.609741 -0.025517    0.0
# 2019- Real data for Philippines Tennessee:[672]
# 2019- Predicted for Philippines Tennessee: 813.7254290618322
# The MAE while testing 2019 for Philippines Tennessee: 141.7254290618322
# The MAPE while testing 2019 for Philippines Tennessee: 0.21090093610391694
# Texas
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              1.055088  -0.09251    0.0
# 2019- Real data for Philippines Texas:[2629]
# 2019- Predicted for Philippines Texas: 3032.417533811944
# The MAE while testing 2019 for Philippines Texas: 403.41753381194394
# The MAPE while testing 2019 for Philippines Texas: 0.15344904291059108
# Utah
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.708537 -0.046799    0.0
# 2019- Real data for Philippines Utah:[202]
# 2019- Predicted for Philippines Utah: 257.82940936719433
# The MAE while testing 2019 for Philippines Utah: 55.82940936719433
# The MAPE while testing 2019 for Philippines Utah: 0.27638321468908084
# Vermont
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.365566 -0.116703    0.0
# 2019- Real data for Philippines Vermont:[23]
# 2019- Predicted for Philippines Vermont: 27.652907155583655
# The MAE while testing 2019 for Philippines Vermont: 4.652907155583655
# The MAPE while testing 2019 for Philippines Vermont: 0.20230031111233285
# Virginia
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.494006 -0.070543    0.0
# 2019- Real data for Philippines Virginia:[1019]
# 2019- Predicted for Philippines Virginia: 1238.1017784745875
# The MAE while testing 2019 for Philippines Virginia: 219.1017784745875
# The MAPE while testing 2019 for Philippines Virginia: 0.2150164656276619
# Washington
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.655591 -0.048182    0.0
# 2019- Real data for Philippines Washington:[1492]
# 2019- Predicted for Philippines Washington: 1385.5415810270526
# The MAE while testing 2019 for Philippines Washington: 106.45841897294736
# The MAPE while testing 2019 for Philippines Washington: 0.07135282772985747
# West Virginia
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.824777 -0.054428    0.0
# 2019- Real data for Philippines West Virginia:[70]
# 2019- Predicted for Philippines West Virginia: 83.61762652582175
# The MAE while testing 2019 for Philippines West Virginia: 13.617626525821748
# The MAPE while testing 2019 for Philippines West Virginia: 0.19453752179745354
# Wisconsin
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.875416  0.042241    0.0
# 2019- Real data for Philippines Wisconsin:[252]
# 2019- Predicted for Philippines Wisconsin: 242.9783498283932
# The MAE while testing 2019 for Philippines Wisconsin: 9.021650171606808
# The MAPE while testing 2019 for Philippines Wisconsin: 0.035800199093677806
# Wyoming
#    Population_total  GDP_per_capita  Urban_population  Birth_rate_crude  \
# 0          0.873293        0.978923          0.772534           0.08471
#
#    Gini_index  GDP_per_capita_state  UR_STATE  Covid
# 0         0.6              0.721152 -0.159071    0.0
# 2019- Real data for Philippines Wyoming:[31]
# 2019- Predicted for Philippines Wyoming: 62.33119823911167
# The MAE while testing 2019 for Philippines Wyoming: 31.33119823911167
# The MAPE while testing 2019 for Philippines Wyoming: 1.0106838141648926
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({
# C:\Users\MIRIAM\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\4178705181.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_scores = df_scores.append({

# %%
df_scores
# Out:
#          Country          State  R2 Score         RMSE      MAPE        MEDAE  \
# 0          China        Alabama       NaN    39.528756  0.256680    39.528756
# 1          China         Alaska       NaN     2.232729  0.067658     2.232729
# 2          China        Arizona       NaN   112.731324  0.226368   112.731324
# 3          China       Arkansas       NaN    12.884396  0.146414    12.884396
# 4          China     California       NaN  1919.128509  0.088832  1919.128509
# ..           ...            ...       ...          ...       ...          ...
# 352  Philippines       Virginia       NaN   219.101778  0.215016   219.101778
# 353  Philippines     Washington       NaN   106.458419  0.071353   106.458419
# 354  Philippines  West Virginia       NaN    13.617627  0.194538    13.617627
# 355  Philippines      Wisconsin       NaN     9.021650  0.035800     9.021650
# 356  Philippines        Wyoming       NaN    31.331198  1.010684    31.331198
#
#          CVRMSE data2019      pred2019
# 0     25.668023    [154]    114.471244
# 1      6.765845     [33]     35.232729
# 2     22.636812    [498]    385.268676
# 3     14.641359     [88]     75.115604
# 4      8.883209  [21604]  19684.871491
# ..          ...      ...           ...
# 352   21.501647   [1019]   1238.101778
# 353    7.135283   [1492]   1385.541581
# 354   19.453752     [70]     83.617627
# 355    3.580020    [252]    242.978350
# 356  101.068381     [31]     62.331198
#
# [357 rows x 9 columns]

# %%
df_scores.describe()
# Out:
#        R2 Score          RMSE          MAPE         MEDAE      CVRMSE  \
# count       0.0    357.000000  3.570000e+02    357.000000  357.000000
# mean        NaN    255.455910  7.659375e+14    255.455910         inf
# std         NaN   1046.933790  6.768355e+15   1046.933790         NaN
# min         NaN      0.090603  1.763725e-03      0.090603    0.176373
# 25%         NaN     14.492078  1.266869e-01     14.492078   12.668688
# 50%         NaN     36.169823  2.422454e-01     36.169823   24.224536
# 75%         NaN    131.140941  4.393076e-01    131.140941   43.930756
# max         NaN  16920.928722  8.243197e+16  16920.928722         inf
#
#            pred2019
# count    357.000000
# mean    1218.890228
# std     4707.086182
# min    -3914.192958
# 25%       53.785722
# 50%      193.591718
# 75%      769.003472
# max    64645.928722

# %%
# Reshape the DataFrame to a pivot table for the heatmap
heatmap_df = df_scores.pivot(index='Country', columns='State', values='MAPE')  # You can choose 'MAPE' here if needed

# Plot the heatmap
plt.figure(figsize=(30, 28))
sns.heatmap(heatmap_df, annot=True, cmap='YlGnBu', fmt=".2f", cbar_kws={'label': 'MAPE'},vmin=0, vmax=1)  # You can choose 'MAPE' here if needed
plt.title('MAPE Heatmap')
plt.xlabel('State')
plt.ylabel('Country')
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

plt.show()

# %%
plt.savefig('heatmap_mape_LR_2019.png', dpi=300, bbox_inches='tight')  d
plt.close()
# Out:
#   File "C:\Users\MIRIAM\AppData\Local\Temp\ipykernel_9244\470437182.py", line 1
#     plt.savefig('heatmap_mape_LR_2019.png', dpi=300, bbox_inches='tight')  d
#                                                                            ^
# SyntaxError: invalid syntax

# %%
df_scores.to_csv("Output/Linear_Regression_predictions_2019.csv", index=False)

# %%
display(df_scores[(df_scores['State'] == 'Wyoming') & (df_scores['Country'] == 'Philippines')])
# Out:
#          Country    State  R2 Score       RMSE      MAPE      MEDAE  \
# 356  Philippines  Wyoming       NaN  31.331198  1.010684  31.331198
#
#          CVRMSE data2019   pred2019
# 356  101.068381     [31]  62.331198

# %%
display(df_scores[(df_scores['State'] == 'West Virginia') & (df_scores['Country'] == 'Dominican Republic')])
# Out:
#                 Country          State  R2 Score      RMSE      MAPE  \
# 150  Dominican Republic  West Virginia       NaN  1.769386  0.196598
#
#         MEDAE     CVRMSE data2019   pred2019
# 150  1.769386  19.659848      [9]  10.769386

# %%
display(df_scores[(df_scores['State'] == 'California') & (df_scores['Country'] == 'United Kingdom')])
# Out:
#             Country       State  R2 Score        RMSE      MAPE       MEDAE  \
# 208  United Kingdom  California       NaN  526.681931  0.245082  526.681931
#
#         CVRMSE data2019     pred2019
# 208  24.508233   [2149]  1622.318069
